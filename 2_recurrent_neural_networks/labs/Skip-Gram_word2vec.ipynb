# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:43, 303kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R 
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:201: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6766 0.0475 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6028 0.0301 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4968 0.0301 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6123 0.0299 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5444 0.0298 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5026 0.0302 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5607 0.0298 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5234 0.0298 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4818 0.0298 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4305 0.0299 sec/batch
# Nearest to his: gilles, parliament, afraid, sleeker, clemency, sometime, ferment, nails,
# Nearest to people: menendez, weiser, attained, lesbians, hst, ectocervix, aorta, customer,
# Nearest to five: eyebrow, specimens, melos, fas, marlins, asahel, gilbert, encouragement,
# Nearest to more: jost, stereotyping, rebellions, demanded, kinnock, tain, alimentary, combined,
# Nearest to when: chhattisgarh, vc, demography, archdukes, armband, manoeuvre, derivation, nugent,
# Nearest to is: compounding, zaire, fray, piste, nadia, diminishes, liquid, tufts,
# Nearest to war: suggestions, mayoral, vicuna, revolt, learnt, injured, succumbed, jfk,
# Nearest to this: institut, catullus, curtiz, hemionus, steadily, newlyweds, softpanorama, appear,
# Nearest to applications: crelle, babysitter, inertial, delavan, symmetries, maniacs, cheques, nihilo,
# Nearest to existence: keita, cancellation, multithreading, wu, role, alu, artes, billion,
# Nearest to brother: leonardo, flash, langue, ipa, du, judoka, chaplains, chivalric,
# Nearest to quite: septuagint, undoubtedly, airs, ams, development, infusions, lode, bao,
# Nearest to liberal: hooking, pinnacles, tracklisting, precept, dentists, tuyere, rinaldo, mehmed,
# Nearest to road: barges, confederate, moynihan, pakenham, yf, antonius, embittered, tipping,
# Nearest to derived: neighbour, entrances, bayonet, pertinent, heathens, monographs, another, symmes,
# Nearest to pressure: guitars, theresa, wis, stoic, wormhole, paramount, sets, villard,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4874 0.0312 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4137 0.0300 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3452 0.0303 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2452 0.0297 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1925 0.0301 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1441 0.0303 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1098 0.0300 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0657 0.0301 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9921 0.0296 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9679 0.0304 sec/batch
# Nearest to his: afraid, parliament, sometime, instruments, usa, lj, hanged, myths,
# Nearest to people: menendez, attained, nine, one, eight, weiser, peninsula, ectocervix,
# Nearest to five: specimens, eyebrow, gilbert, encouragement, marlins, examine, competitions, fas,
# Nearest to more: demanded, rebellions, jost, combined, struggle, say, remains, latino,
# Nearest to when: derivation, demography, vc, armband, nugent, manoeuvre, chhattisgarh, european,
# Nearest to is: zaire, compounding, imaging, dying, liquid, mean, promote, answer,
# Nearest to war: suggestions, revolt, learnt, darkness, associated, slightly, injured, starts,
# Nearest to this: appear, institut, curtiz, catullus, attraction, steadily, hemionus, without,
# Nearest to applications: crelle, symmetries, babysitter, physical, inertial, its, satie, coastal,
# Nearest to existence: role, keita, cancellation, wu, alu, belief, billion, followers,
# Nearest to brother: leonardo, flash, ipa, harm, du, truly, identical, decree,
# Nearest to quite: septuagint, undoubtedly, development, airs, playing, airport, infusions, tunnelling,
# Nearest to liberal: hooking, pinnacles, precept, tracklisting, mehmed, criseyde, tuyere, rinaldo,
# Nearest to road: barges, limited, confederate, something, held, moynihan, permit, aware,
# Nearest to derived: neighbour, another, pertinent, entrances, realistic, passes, structures, heathens,
# Nearest to pressure: guitars, theresa, sets, anachronisms, institute, stoic, making, paramount,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9409 0.0311 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8792 0.0299 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8749 0.0302 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8363 0.0300 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8080 0.0303 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8106 0.0305 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7878 0.0309 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7812 0.0298 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8041 0.0300 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7647 0.0303 sec/batch
# Nearest to his: parliament, sometime, afraid, gilles, treblinka, nails, magdalena, instruments,
# Nearest to people: menendez, attained, weiser, peninsula, underemployed, customer, ectocervix, gettysburg,
# Nearest to five: specimens, encouragement, examine, eyebrow, fas, marlins, sicilies, gilbert,
# Nearest to more: jost, demanded, rebellions, say, objections, stereotyping, reflexes, wisdom,
# Nearest to when: derivation, demography, vc, chhattisgarh, armband, manoeuvre, providers, nugent,
# Nearest to is: compounding, zaire, nadia, liquid, imaging, mean, sensitive, answer,
# Nearest to war: suggestions, revolt, learnt, injured, mayoral, executed, darkness, liberalization,
# Nearest to this: institut, curtiz, steadily, catullus, attraction, appear, multinational, hemionus,
# Nearest to applications: crelle, symmetries, inertial, babysitter, satie, physical, boise, generic,
# Nearest to existence: role, cancellation, followers, keita, wu, alu, belief, hesitation,
# Nearest to brother: leonardo, flash, ipa, langue, harm, vertical, earthquakes, positioned,
# Nearest to quite: septuagint, undoubtedly, development, airs, infusions, airport, playing, max,
# Nearest to liberal: hooking, pinnacles, precept, mehmed, criseyde, framed, communion, diplomacy,
# Nearest to road: barges, limited, confederate, permit, moynihan, held, something, embittered,
# Nearest to derived: neighbour, passes, pertinent, realistic, another, entrances, teleplay, heathens,
# Nearest to pressure: theresa, guitars, gulf, paramount, niven, anachronisms, composites, sets,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7844 0.0310 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7702 0.0299 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7026 0.0302 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7382 0.0304 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7349 0.0303 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6985 0.0301 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6982 0.0300 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7188 0.0301 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7097 0.0301 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6852 0.0302 sec/batch
# Nearest to his: magdalena, sometime, afraid, nails, parliament, treblinka, heroine, gilles,
# Nearest to people: menendez, weiser, attained, lesbians, gettysburg, underemployed, fukuyama, peninsula,
# Nearest to five: four, three, fas, eyebrow, sicilies, sebastian, two, one,
# Nearest to more: jost, rebellions, reflexes, demanded, combined, objections, astronaut, say,
# Nearest to when: demography, chhattisgarh, derivation, vc, manoeuvre, archdukes, nugent, endowment,
# Nearest to is: compounding, liquid, zaire, fray, imaging, nadia, thrive, deficiency,
# Nearest to war: revolt, learnt, suggestions, latimer, mayoral, iraq, injured, establishing,
# Nearest to this: institut, catullus, curtiz, appear, attraction, steadily, softpanorama, ascending,
# Nearest to applications: crelle, symmetries, inertial, boise, extinguished, physical, coc, satie,
# Nearest to existence: cancellation, keita, followers, role, alu, belief, freeways, whigs,
# Nearest to brother: leonardo, flash, ipa, langue, judoka, mussels, chaplains, harm,
# Nearest to quite: undoubtedly, septuagint, airs, infusions, beheld, playing, development, airport,
# Nearest to liberal: hooking, pinnacles, precept, mehmed, popper, criseyde, party, tracklisting,
# Nearest to road: barges, confederate, antonius, limited, yf, moynihan, pakenham, alvarez,
# Nearest to derived: neighbour, pertinent, bayonet, cave, entrances, passes, realistic, teleplay,
# Nearest to pressure: theresa, guitars, gulf, nostalgia, composites, trafalgar, anachronisms, paramount,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6586 0.0308 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6696 0.0302 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6182 0.0302 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6192 0.0302 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6419 0.0299 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6263 0.0311 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6037 0.0224 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5717 0.0298 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5209 0.0300 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5000 0.0301 sec/batch
# Nearest to his: magdalena, sometime, treblinka, nails, clemency, parliament, heroine, he,
# Nearest to people: menendez, weiser, lesbians, gettysburg, attained, hst, underemployed, cricket,
# Nearest to five: four, three, two, one, sicilies, sebastian, composer, eyebrow,
# Nearest to more: rebellions, jost, combined, theorizing, reflexes, objections, say, kinnock,
# Nearest to when: demography, chhattisgarh, vc, derivation, archdukes, manoeuvre, armband, finnegans,
# Nearest to is: compounding, liquid, fray, imaging, zaire, behave, mean, thrive,
# Nearest to war: revolt, latimer, learnt, iraq, boyne, against, suggestions, injured,
# Nearest to this: institut, appear, curtiz, softpanorama, catullus, without, slalom, gathering,
# Nearest to applications: crelle, symmetries, inertial, boise, physical, coc, extinguished, generic,
# Nearest to existence: keita, followers, cancellation, belief, role, alu, blissymbols, multithreading,
# Nearest to brother: leonardo, voronin, langue, chaplains, judoka, flash, scarcely, lament,
# Nearest to quite: undoubtedly, septuagint, infusions, playing, beheld, airs, development, gillian,
# Nearest to liberal: hooking, pinnacles, precept, party, popper, mehmed, criseyde, tracklisting,
# Nearest to road: barges, antonius, confederate, pakenham, yf, cranial, reprint, adjusting,
# Nearest to derived: pertinent, bayonet, heathens, structures, realistic, passes, neighbour, cave,
# Nearest to pressure: theresa, guitars, composites, gulf, nostalgia, quickest, stoic, diluted,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5131 0.0310 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4910 0.0302 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4544 0.0302 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5263 0.0303 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5014 0.0303 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4945 0.0305 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4535 0.0299 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3939 0.0305 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4442 0.0304 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4122 0.0314 sec/batch
# Nearest to his: magdalena, he, sometime, clemency, heroine, treblinka, afraid, nails,
# Nearest to people: menendez, weiser, lesbians, attained, gettysburg, fukuyama, underemployed, hst,
# Nearest to five: four, three, two, eyebrow, fas, specimens, sebastian, melos,
# Nearest to more: combined, reflexes, jost, apples, rebellions, theorizing, say, often,
# Nearest to when: demography, vc, chhattisgarh, armband, derivation, endowment, archdukes, manoeuvre,
# Nearest to is: compounding, liquid, nadia, behave, sensitive, mean, zaire, fray,
# Nearest to war: revolt, iraq, against, learnt, boyne, latimer, establishing, suggestions,
# Nearest to this: institut, without, differ, appear, catullus, softpanorama, slalom, hemionus,
# Nearest to applications: crelle, inertial, symmetries, physical, generic, boise, coc, embedded,
# Nearest to existence: keita, followers, belief, role, cancellation, alu, multithreading, blissymbols,
# Nearest to brother: leonardo, voronin, zmir, chaplains, judoka, lament, emilia, langue,
# Nearest to quite: undoubtedly, septuagint, infusions, playing, beheld, gillian, suarez, tunnelling,
# Nearest to liberal: hooking, party, pinnacles, precept, veto, however, popper, cabinet,
# Nearest to road: barges, antonius, confederate, pakenham, metro, yf, climatology, reprint,
# Nearest to derived: bayonet, pertinent, passes, vigorous, heathens, structures, conducting, rublev,
# Nearest to pressure: composites, diluted, guitars, nostalgia, stoic, theresa, quickest, deckers,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4709 0.0327 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4251 0.0315 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4299 0.0307 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4223 0.0304 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4060 0.0303 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4641 0.0301 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4121 0.0301 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4004 0.0303 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4222 0.0304 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3996 0.0304 sec/batch
# Nearest to his: he, magdalena, afraid, treblinka, heroine, clemency, sometime, nails,
# Nearest to people: menendez, lesbians, attained, weiser, gettysburg, cricket, fukuyama, peninsula,
# Nearest to five: four, three, two, eyebrow, one, fas, sebastian, female,
# Nearest to more: combined, reflexes, theorizing, jost, rebellions, uninformed, objections, alimentary,
# Nearest to when: demography, chhattisgarh, vc, ball, manoeuvre, alchemists, archdukes, finnegans,
# Nearest to is: compounding, piste, mean, behave, liquid, fray, nadia, generator,
# Nearest to war: revolt, latimer, iraq, injured, learnt, against, establishing, outnumbering,
# Nearest to this: slalom, institut, catullus, sensibility, without, rupee, attraction, appear,
# Nearest to applications: crelle, symmetries, generic, inertial, physical, embedded, boise, coc,
# Nearest to existence: belief, keita, followers, role, cancellation, multithreading, blissymbols, alu,
# Nearest to brother: leonardo, voronin, zmir, chaplains, confidentially, lament, cyrus, emilia,
# Nearest to quite: undoubtedly, septuagint, infusions, playing, beheld, shelved, gillian, expiration,
# Nearest to liberal: hooking, party, pinnacles, precept, veto, however, popper, shays,
# Nearest to road: barges, antonius, confederate, metro, pakenham, yf, gallery, climatology,
# Nearest to derived: vigorous, heathens, cave, bayonet, pertinent, rublev, conducting, movimiento,
# Nearest to pressure: composites, diluted, diameter, rays, nostalgia, quickest, neutron, enthalpy,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3868 0.0315 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3945 0.0305 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3465 0.0303 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3558 0.0305 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4257 0.0308 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3452 0.0308 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3839 0.0311 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4101 0.0307 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3412 0.0308 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3177 0.0306 sec/batch
# Nearest to his: he, magdalena, afraid, treblinka, pannonia, clemency, sometime, heroine,
# Nearest to people: menendez, lesbians, fukuyama, adventist, weiser, cricket, attained, hst,
# Nearest to five: four, three, two, eyebrow, one, fas, six, female,
# Nearest to more: reflexes, theorizing, combined, jost, rebellions, often, alimentary, troll,
# Nearest to when: demography, chhattisgarh, ball, vc, transgressive, manoeuvre, brunette, derivation,
# Nearest to is: compounding, piste, mean, behave, thrive, vulgate, spherically, nadia,
# Nearest to war: revolt, against, iraq, injured, latimer, allied, establishing, during,
# Nearest to this: institut, slalom, attraction, catullus, sensibility, rupee, schichau, contradiction,
# Nearest to applications: crelle, generic, symmetries, inertial, embedded, cheaper, physical, coc,
# Nearest to existence: belief, keita, followers, role, blissymbols, multithreading, cancellation, alu,
# Nearest to brother: leonardo, voronin, zmir, heirs, chaplains, cyrus, confidentially, emilia,
# Nearest to quite: undoubtedly, infusions, septuagint, playing, beheld, worldstatesmen, shelved, gillian,
# Nearest to liberal: hooking, precept, veto, party, pinnacles, however, tracklisting, shays,
# Nearest to road: barges, metro, antonius, confederate, cranial, pipelines, gallery, tipping,
# Nearest to derived: heathens, vigorous, phrases, rublev, bayonet, movimiento, conducting, pertinent,
# Nearest to pressure: composites, diluted, quickest, nostalgia, gulf, wormhole, anachronisms, enthalpy,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3666 0.0319 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3014 0.0307 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3866 0.0308 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3947 0.0304 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3707 0.0308 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2942 0.0303 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3031 0.0300 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3513 0.0302 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2148 0.0302 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2841 0.0302 sec/batch
# Nearest to his: afraid, he, magdalena, treblinka, clemency, disliking, pannonia, heroine,
# Nearest to people: menendez, lesbians, fukuyama, adventist, weiser, cricket, peninsula, attained,
# Nearest to five: four, three, two, one, six, eight, zero, eyebrow,
# Nearest to more: reflexes, combined, theorizing, jost, alimentary, rebellions, often, troll,
# Nearest to when: chhattisgarh, demography, ball, transgressive, vc, duby, brunette, langton,
# Nearest to is: compounding, mean, piste, y, vulgate, behave, generator, spherically,
# Nearest to war: revolt, injured, iraq, allied, against, executed, during, boyne,
# Nearest to this: institut, catullus, slalom, contradiction, schichau, rigid, rupee, sensibility,
# Nearest to applications: crelle, generic, symmetries, embedded, switcher, cheaper, inertial, commercialization,
# Nearest to existence: keita, belief, followers, role, blissymbols, cancellation, multithreading, truth,
# Nearest to brother: leonardo, voronin, zmir, heirs, confidentially, emilia, eldest, chaplains,
# Nearest to quite: undoubtedly, infusions, septuagint, playing, worldstatesmen, applescript, gillian, shelved,
# Nearest to liberal: hooking, party, precept, pinnacles, however, tracklisting, democrat, veto,
# Nearest to road: barges, metro, antonius, cranial, tipping, confederate, roanoke, yf,
# Nearest to derived: heathens, vigorous, rublev, tilt, bayonet, phrases, pertinent, conducting,
# Nearest to pressure: composites, diluted, nostalgia, gulf, quickest, anachronisms, modernes, peremptory,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3055 0.0311 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2872 0.0300 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3494 0.0139 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2525 0.0301 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2528 0.0306 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2289 0.0303 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2211 0.0304 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2216 0.0301 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2217 0.0302 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1669 0.0302 sec/batch
# Nearest to his: he, afraid, magdalena, pannonia, clemency, sometime, treblinka, disliking,
# Nearest to people: menendez, weiser, lesbians, cricket, fukuyama, adventist, attained, nyc,
# Nearest to five: four, three, two, one, six, zero, eight, fas,
# Nearest to more: reflexes, combined, theorizing, mnemonics, illiniwek, often, alimentary, troll,
# Nearest to when: demography, ball, duby, rhinoceroses, chhattisgarh, understandably, transgressive, akston,
# Nearest to is: compounding, piste, mean, thrive, fray, nadia, habitations, datagram,
# Nearest to war: injured, revolt, against, allied, during, executed, iraq, latimer,
# Nearest to this: slalom, catullus, institut, wedges, spain, sensibility, attraction, ballista,
# Nearest to applications: crelle, generic, symmetries, embedded, switcher, cheaper, inertial, commercialization,
# Nearest to existence: followers, belief, keita, role, blissymbols, truth, explained, cancellation,
# Nearest to brother: leonardo, voronin, zmir, heirs, emilia, mcfadden, confidentially, eldest,
# Nearest to quite: undoubtedly, infusions, septuagint, playing, beheld, applescript, worldstatesmen, gillian,
# Nearest to liberal: hooking, party, precept, tracklisting, democrat, however, pinnacles, popper,
# Nearest to road: barges, metro, antonius, tipping, pipelines, gallery, cranial, hippos,
# Nearest to derived: heathens, vigorous, rublev, phrases, bayonet, amorality, pertinent, continent,
# Nearest to pressure: composites, diluted, quickest, enthalpy, determined, anachronisms, shock, wormhole,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2547 0.0315 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2503 0.0303 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2467 0.0303 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1382 0.0301 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1721 0.0305 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1562 0.0301 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1314 0.0298 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1969 0.0302 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1615 0.0298 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2070 0.0299 sec/batch
# Nearest to his: afraid, he, wit, magdalena, clemency, treblinka, heroine, disliking,
# Nearest to people: menendez, weiser, adventist, lesbians, cricket, nyc, fukuyama, penguins,
# Nearest to five: four, three, two, one, six, zero, female, fas,
# Nearest to more: combined, theorizing, reflexes, often, mnemonics, uninformed, unloaded, alimentary,
# Nearest to when: demography, ball, understandably, langton, rhinoceroses, emergency, transgressive, unless,
# Nearest to is: compounding, mean, piste, generator, nadia, behave, y, datagram,
# Nearest to war: injured, revolt, allied, against, during, latimer, warfare, iraq,
# Nearest to this: slalom, catullus, appear, attraction, cdots, rigid, lunations, treads,
# Nearest to applications: crelle, generic, embedded, symmetries, switcher, cheaper, design, commercialization,
# Nearest to existence: keita, belief, followers, role, blissymbols, explained, cancellation, truth,
# Nearest to brother: leonardo, voronin, zmir, heirs, emilia, confidentially, cyrus, sexy,
# Nearest to quite: undoubtedly, infusions, septuagint, beheld, applescript, solent, gillian, worldstatesmen,
# Nearest to liberal: hooking, party, democrat, tracklisting, however, popper, precept, shays,
# Nearest to road: metro, barges, tipping, gallery, antonius, encroaching, heliports, confederate,
# Nearest to derived: phrases, heathens, vigorous, rublev, amorality, tilt, conducting, hanyu,
# Nearest to pressure: composites, enthalpy, quickest, shock, diluted, determined, rays, diameter,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1898 0.0310 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2620 0.0299 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1976 0.0299 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1519 0.0303 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2058 0.0303 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1839 0.0305 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2083 0.0306 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1781 0.0303 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1365 0.0303 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1904 0.0302 sec/batch
# Nearest to his: he, afraid, wit, treblinka, disliking, clemency, magdalena, kindly,
# Nearest to people: menendez, adventist, cricket, weiser, lesbians, fukuyama, penguins, nyc,
# Nearest to five: four, three, two, one, six, zero, eight, female,
# Nearest to more: theorizing, combined, unloaded, mnemonics, alimentary, reflexes, jost, illiniwek,
# Nearest to when: ball, demography, understandably, transgressive, akston, brunette, chhattisgarh, unless,
# Nearest to is: compounding, mean, piste, vulgate, spherically, nadia, y, prokaryotes,
# Nearest to war: injured, revolt, allied, latimer, against, during, executed, warfare,
# Nearest to this: slalom, spain, catullus, wedges, attraction, institut, cdots, lunations,
# Nearest to applications: crelle, generic, symmetries, embedded, switcher, existing, design, commercialization,
# Nearest to existence: belief, keita, followers, explained, role, blissymbols, subatomic, truth,
# Nearest to brother: leonardo, heirs, voronin, zmir, emilia, younger, cyrus, eldest,
# Nearest to quite: undoubtedly, infusions, septuagint, solent, applescript, gillian, worldstatesmen, playing,
# Nearest to liberal: party, hooking, democrat, conservative, popper, however, tracklisting, shays,
# Nearest to road: metro, barges, tipping, antonius, cranial, gallery, wwe, encroaching,
# Nearest to derived: heathens, phrases, vigorous, rublev, amorality, transliteration, hanyu, another,
# Nearest to pressure: enthalpy, composites, shock, quickest, diluted, diameter, gulf, determined,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1882 0.0312 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1568 0.0304 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1748 0.0302 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1832 0.0304 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1265 0.0302 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1181 0.0301 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1650 0.0298 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1299 0.0300 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1968 0.0301 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2345 0.0304 sec/batch
# Nearest to his: he, treblinka, afraid, disliking, wit, magdalena, kindly, clemency,
# Nearest to people: menendez, adventist, weiser, cricket, lesbians, fukuyama, ica, racial,
# Nearest to five: four, three, two, one, six, zero, eight, female,
# Nearest to more: theorizing, combined, jost, mnemonics, alimentary, unloaded, troll, wim,
# Nearest to when: transgressive, understandably, noah, akston, ball, demography, brunette, rhinoceroses,
# Nearest to is: piste, mean, compounding, vulgate, nadia, paraphrase, thrive, icelandic,
# Nearest to war: injured, revolt, allied, latimer, warfare, against, during, executed,
# Nearest to this: catullus, spain, slalom, wedges, rupee, amended, lunations, earldom,
# Nearest to applications: crelle, generic, symmetries, switcher, existing, embedded, commercialization, staffing,
# Nearest to existence: keita, followers, belief, explained, role, blissymbols, chaste, aru,
# Nearest to brother: leonardo, heirs, zmir, younger, voronin, eldest, emilia, cyrus,
# Nearest to quite: undoubtedly, septuagint, infusions, solent, applescript, playing, beheld, gillian,
# Nearest to liberal: party, hooking, democrat, however, popper, conservative, tracklisting, shays,
# Nearest to road: barges, metro, tipping, antonius, cranial, wwe, encroaching, gallery,
# Nearest to derived: heathens, phrases, vigorous, amorality, rublev, transliteration, hanyu, derives,
# Nearest to pressure: shock, gulf, enthalpy, composites, quickest, theresa, diluted, peremptory,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2531 0.0309 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1461 0.0299 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1534 0.0300 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1387 0.0297 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0485 0.0300 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1320 0.0299 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1552 0.0300 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1347 0.0299 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1539 0.0054 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1273 0.0301 sec/batch
# Nearest to his: he, treblinka, afraid, disliking, wit, kindly, magdalena, clemency,
# Nearest to people: weiser, adventist, cricket, menendez, lesbians, racial, ica, attained,
# Nearest to five: four, three, two, one, six, zero, eight, female,
# Nearest to more: theorizing, combined, unloaded, mnemonics, often, alimentary, troll, battles,
# Nearest to when: ball, understandably, akston, transgressive, demography, brunette, tries, noah,
# Nearest to is: mean, piste, compounding, vulgate, monsoon, spherically, intangible, datagram,
# Nearest to war: injured, revolt, executed, allied, against, during, warfare, latimer,
# Nearest to this: catullus, slalom, wedges, rupee, gathering, treads, lunations, laboriously,
# Nearest to applications: crelle, generic, symmetries, switcher, existing, embedded, its, design,
# Nearest to existence: keita, followers, belief, blissymbols, explained, role, aru, annihilation,
# Nearest to brother: leonardo, heirs, younger, zmir, eldest, emilia, cyrus, voronin,
# Nearest to quite: undoubtedly, infusions, septuagint, solent, applescript, playing, neatly, snoop,
# Nearest to liberal: party, hooking, democrat, popper, tracklisting, conservative, however, shays,
# Nearest to road: metro, barges, tipping, wwe, cranial, antonius, pipelines, lanes,
# Nearest to derived: phrases, heathens, vigorous, rublev, transliteration, derives, khuzestan, amorality,
# Nearest to pressure: shock, enthalpy, gulf, theresa, composites, quickest, peremptory, modernes,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0933 0.0310 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0922 0.0302 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1065 0.0302 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0560 0.0299 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0701 0.0301 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0155 0.0304 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0823 0.0310 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1046 0.0299 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0889 0.0299 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0205 0.0301 sec/batch
# Nearest to his: he, treblinka, wit, afraid, kindly, disliking, clemency, magdalena,
# Nearest to people: weiser, cricket, menendez, adventist, racial, lesbians, ica, sino,
# Nearest to five: four, three, two, one, six, zero, eight, female,
# Nearest to more: theorizing, combined, often, unloaded, mnemonics, executables, troll, stereotyping,
# Nearest to when: ball, understandably, akston, blocked, transgressive, tries, brunette, demography,
# Nearest to is: mean, compounding, piste, spherically, intangible, datagram, the, hoagie,
# Nearest to war: injured, revolt, against, allied, warfare, iraq, during, latimer,
# Nearest to this: rupee, treads, lunations, laboriously, catullus, spain, parametric, churchmen,
# Nearest to applications: crelle, generic, symmetries, embedded, switcher, design, existing, its,
# Nearest to existence: keita, followers, belief, blissymbols, explained, role, cancellation, aru,
# Nearest to brother: leonardo, emilia, voronin, younger, zmir, convalescence, heirs, retired,
# Nearest to quite: undoubtedly, septuagint, infusions, solent, applescript, snoop, transmuted, playing,
# Nearest to liberal: party, democrat, hooking, tracklisting, popper, conservative, however, shays,
# Nearest to road: metro, barges, lanes, highway, tipping, wwe, pipelines, antonius,
# Nearest to derived: phrases, heathens, rublev, vigorous, transliteration, amorality, derives, khuzestan,
# Nearest to pressure: enthalpy, shock, composites, gulf, diameter, quickest, anachronisms, wormhole,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0093 0.0308 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0047 0.0299 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0249 0.0295 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0531 0.0301 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0704 0.0297 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0569 0.0299 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0691 0.0300 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0851 0.0298 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0770 0.0298 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0483 0.0297 sec/batch
# Nearest to his: he, wit, treblinka, afraid, kindly, disliking, clemency, goodnight,
# Nearest to people: weiser, menendez, cricket, racial, adventist, lesbians, underemployed, sino,
# Nearest to five: four, three, two, one, six, zero, eight, female,
# Nearest to more: theorizing, combined, unloaded, mnemonics, often, executables, stereotyping, defintion,
# Nearest to when: ball, understandably, akston, brunette, rhinoceroses, transgressive, paged, tries,
# Nearest to is: mean, piste, compounding, of, vulgate, y, denoted, spherically,
# Nearest to war: injured, revolt, latimer, against, allied, warfare, iraq, during,
# Nearest to this: cdots, catullus, parametric, slalom, lunations, rupee, laboriously, treads,
# Nearest to applications: crelle, generic, switcher, design, symmetries, embedded, existing, bcd,
# Nearest to existence: keita, belief, followers, blissymbols, explained, role, cosmology, annihilation,
# Nearest to brother: leonardo, emilia, zmir, younger, voronin, eldest, convalescence, cyrus,
# Nearest to quite: undoubtedly, septuagint, infusions, solent, playing, snoop, applescript, cute,
# Nearest to liberal: party, democrat, hooking, conservative, tracklisting, popper, shays, however,
# Nearest to road: metro, barges, lanes, tipping, highway, wwe, antonius, pla,
# Nearest to derived: phrases, heathens, vigorous, rublev, amorality, another, khuzestan, derives,
# Nearest to pressure: enthalpy, shock, pump, composites, thermodynamic, gulf, taglioni, determined,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0574 0.0310 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0706 0.0304 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0370 0.0310 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0660 0.0309 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0577 0.0312 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0315 0.0298 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0654 0.0299 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0564 0.0300 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1041 0.0301 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0779 0.0300 sec/batch
# Nearest to his: he, treblinka, wit, afraid, disliking, kindly, clemency, magdalena,
# Nearest to people: cricket, menendez, racial, weiser, adventist, lesbians, ica, sino,
# Nearest to five: four, three, two, one, six, zero, eight, female,
# Nearest to more: theorizing, combined, executables, unloaded, often, better, mnemonics, defintion,
# Nearest to when: understandably, brunette, transgressive, blocked, akston, noah, ball, livorno,
# Nearest to is: mean, piste, compounding, intangible, paraphrase, vulgate, neuroses, spherically,
# Nearest to war: injured, revolt, against, latimer, during, allied, warfare, executed,
# Nearest to this: rupee, spain, lunations, earldom, treads, catullus, symbolising, slalom,
# Nearest to applications: crelle, generic, symmetries, switcher, design, embedded, existing, its,
# Nearest to existence: keita, followers, belief, blissymbols, role, explained, annihilation, cosmology,
# Nearest to brother: leonardo, emilia, eldest, heirs, cyrus, younger, zmir, voronin,
# Nearest to quite: undoubtedly, infusions, septuagint, solent, applescript, snoop, playing, transmuted,
# Nearest to liberal: party, conservative, democrat, hooking, popper, shays, liberalism, however,
# Nearest to road: metro, barges, lanes, highway, tipping, lassen, wwe, cranial,
# Nearest to derived: phrases, heathens, transliteration, rublev, vigorous, another, derives, amorality,
# Nearest to pressure: enthalpy, shock, thermodynamic, composites, taglioni, pump, gulf, broadening,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0734 0.0311 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0006 0.0300 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0405 0.0299 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0867 0.0300 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0776 0.0302 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1158 0.0299 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1312 0.0297 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0474 0.0299 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0686 0.0300 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0608 0.0297 sec/batch
# Nearest to his: he, treblinka, wit, disliking, afraid, clemency, upsets, magdalena,
# Nearest to people: weiser, racial, adventist, menendez, cricket, ica, sino, lesbians,
# Nearest to five: four, two, three, one, six, zero, eight, female,
# Nearest to more: theorizing, often, executables, unloaded, combined, troll, defintion, context,
# Nearest to when: understandably, transgressive, akston, brunette, blocked, chhattisgarh, langton, vojt,
# Nearest to is: mean, piste, compounding, y, the, spherically, vulgate, datagram,
# Nearest to war: injured, revolt, latimer, against, warfare, allied, establishing, during,
# Nearest to this: spain, earldom, lunations, cdots, rigid, rupee, catullus, ignoring,
# Nearest to applications: crelle, generic, switcher, design, symmetries, embedded, its, existing,
# Nearest to existence: keita, followers, belief, blissymbols, role, cancellation, annihilation, chaste,
# Nearest to brother: emilia, younger, leonardo, heirs, zmir, eldest, retired, voronin,
# Nearest to quite: undoubtedly, solent, infusions, septuagint, applescript, snoop, silenced, playing,
# Nearest to liberal: party, democrat, conservative, hooking, popper, tracklisting, however, shays,
# Nearest to road: metro, barges, highway, tipping, lanes, wwe, imp, rocky,
# Nearest to derived: phrases, heathens, transliteration, rublev, khuzestan, derives, quenya, fronting,
# Nearest to pressure: shock, enthalpy, pump, peremptory, gulf, siouxsie, taglioni, composites,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0069 0.0307 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0085 0.0301 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0343 0.0298 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0337 0.0300 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0908 0.0301 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0414 0.0268 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0272 0.0298 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9846 0.0302 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0256 0.0300 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9824 0.0298 sec/batch
# Nearest to his: he, treblinka, wit, magdalena, disliking, clemency, kindly, afraid,
# Nearest to people: racial, weiser, menendez, cricket, adventist, sino, writers, leung,
# Nearest to five: four, three, two, one, six, zero, eight, seven,
# Nearest to more: theorizing, executables, often, indirection, context, combined, unloaded, defintion,
# Nearest to when: understandably, transgressive, akston, blocked, vojt, tries, brunette, ball,
# Nearest to is: mean, piste, vulgate, of, the, compounding, as, paraphrase,
# Nearest to war: injured, revolt, latimer, against, warfare, merv, condemning, combatants,
# Nearest to this: lunations, rupee, spain, earldom, converting, gathering, rigid, collagen,
# Nearest to applications: crelle, design, symmetries, generic, its, embedded, switcher, existing,
# Nearest to existence: keita, followers, belief, blissymbols, role, cancellation, explained, absence,
# Nearest to brother: emilia, younger, leonardo, heirs, retired, voronin, eldest, zmir,
# Nearest to quite: undoubtedly, solent, infusions, septuagint, snoop, applescript, playing, silenced,
# Nearest to liberal: party, democrat, conservative, popper, hooking, tracklisting, ideology, however,
# Nearest to road: barges, metro, lanes, tipping, highway, imp, wwe, cranial,
# Nearest to derived: phrases, heathens, transliteration, rublev, derives, conducting, amorality, bayonet,
# Nearest to pressure: enthalpy, shock, pump, peremptory, siouxsie, broadening, thermodynamic, taglioni,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9714 0.0308 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9555 0.0302 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0204 0.0298 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0373 0.0299 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0383 0.0298 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0007 0.0299 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9008 0.0298 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9716 0.0298 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9491 0.0299 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9801 0.0297 sec/batch
# Nearest to his: he, wit, treblinka, clemency, disliking, afraid, kindly, evict,
# Nearest to people: weiser, menendez, racial, cricket, adventist, writers, sino, ica,
# Nearest to five: four, three, two, one, six, zero, eight, seven,
# Nearest to more: theorizing, often, executables, context, unloaded, better, indirection, combined,
# Nearest to when: understandably, ball, paged, akston, transgressive, blocked, colecovision, brunette,
# Nearest to is: the, mean, of, as, piste, porosity, in, and,
# Nearest to war: injured, revolt, warfare, against, latimer, combatants, merv, allied,
# Nearest to this: lunations, spain, collagen, rupee, treads, converting, steadily, to,
# Nearest to applications: crelle, generic, symmetries, design, embedded, bcd, existing, switcher,
# Nearest to existence: keita, followers, belief, cancellation, blissymbols, role, explained, truth,
# Nearest to brother: leonardo, emilia, younger, retired, voronin, heirs, bran, convalescence,
# Nearest to quite: undoubtedly, solent, infusions, snoop, septuagint, it, silenced, applescript,
# Nearest to liberal: democrat, party, conservative, hooking, popper, however, shays, tracklisting,
# Nearest to road: metro, barges, lanes, tipping, highway, imp, wwe, rocky,
# Nearest to derived: phrases, heathens, derives, rublev, transliteration, another, conducting, fronting,
# Nearest to pressure: enthalpy, shock, thermodynamic, broadening, peremptory, composites, anachronisms, pump,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9809 0.0310 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0271 0.0299 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9543 0.0299 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0593 0.0299 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0373 0.0300 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9534 0.0302 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0117 0.0299 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0212 0.0300 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9600 0.0302 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9972 0.0299 sec/batch
# Nearest to his: he, wit, clemency, treblinka, disliking, kindly, evict, afraid,
# Nearest to people: racial, menendez, weiser, cricket, adventist, sino, leung, ica,
# Nearest to five: four, two, three, one, six, zero, eight, seven,
# Nearest to more: theorizing, context, better, defintion, executables, often, understood, stereotyping,
# Nearest to when: understandably, transgressive, blocked, ball, brunette, akston, paged, waxes,
# Nearest to is: the, mean, of, as, piste, paraphrase, promote, vulgate,
# Nearest to war: injured, latimer, revolt, warfare, merv, modernized, against, combatants,
# Nearest to this: spain, rupee, cdots, lunations, catullus, an, mistakenly, shouldn,
# Nearest to applications: crelle, generic, symmetries, existing, embedded, design, switcher, bcd,
# Nearest to existence: keita, belief, followers, blissymbols, explained, cosmology, cancellation, absence,
# Nearest to brother: emilia, younger, leonardo, retired, voronin, eldest, heirs, zmir,
# Nearest to quite: undoubtedly, solent, infusions, snoop, silenced, septuagint, applescript, playing,
# Nearest to liberal: democrat, party, conservative, hooking, popper, however, shays, liberalism,
# Nearest to road: barges, metro, lanes, tipping, highway, wwe, pla, imp,
# Nearest to derived: phrases, heathens, derives, rublev, another, baixa, surname, vigorous,
# Nearest to pressure: enthalpy, thermodynamic, shock, broadening, pump, nostalgia, composites, alloying,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0021 0.0309 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9839 0.0297 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9900 0.0301 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0026 0.0298 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0346 0.0297 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0007 0.0300 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0013 0.0299 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9740 0.0299 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9177 0.0298 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0125 0.0302 sec/batch
# Nearest to his: he, wit, clemency, treblinka, evict, disliking, assistant, afraid,
# Nearest to people: racial, adventist, menendez, cricket, sino, whites, children, weiser,
# Nearest to five: four, two, three, one, six, zero, eight, seven,
# Nearest to more: theorizing, better, often, context, defintion, karajan, battles, firmer,
# Nearest to when: understandably, transgressive, paged, blocked, akston, imperfective, colecovision, refuses,
# Nearest to is: the, of, as, mean, a, and, in, piste,
# Nearest to war: injured, revolt, against, warfare, latimer, modernized, combatants, during,
# Nearest to this: spain, perceiving, catullus, rupee, mistakenly, treads, an, gathering,
# Nearest to applications: crelle, generic, symmetries, existing, embedded, switcher, bcd, its,
# Nearest to existence: keita, followers, belief, cancellation, blissymbols, cosmology, truth, role,
# Nearest to brother: emilia, younger, eldest, leonardo, retired, voronin, zmir, convalescence,
# Nearest to quite: undoubtedly, solent, infusions, it, silenced, snoop, plucking, transmuted,
# Nearest to liberal: party, democrat, hooking, however, conservative, popper, tracklisting, shays,
# ...
# Nearest to people: novelists, writers, births, autodidacts, seattleites, kimono, celebrities, razzie,
# Nearest to five: four, two, one, three, zero, six, eight, seven,
# Nearest to more: theorizing, less, better, and, with, karajan, some, only,
# Nearest to when: to, had, could, because, blocked, only, paged, it,
# Nearest to is: a, of, the, as, and, in, be, an,
# Nearest to war: combatants, combat, vietnam, germans, emergency, nleutnant, equivocal, ii,
# Nearest to this: an, is, to, the, that, be, in, of,
# Nearest to applications: crelle, embedded, symmetries, ergonomics, enchantments, heber, standardise, wide,
# Nearest to existence: cancellation, keita, universe, standing, cn, cosmology, followers, blissymbols,
# Nearest to brother: emilia, son, bachchan, younger, eldest, mcfadden, leonardo, tyndareus,
# Nearest to quite: solent, undoubtedly, it, extrapolating, snoop, raeben, cute, monosyllabic,
# Nearest to liberal: party, democrat, conservative, ideology, hooking, liberalism, sportswriters, capitalism,
# Nearest to road: highway, lanes, tipping, ramps, barges, metro, biking, highways,
# Nearest to derived: heathens, compiles, fronting, pickford, nonresident, baixa, hendrick, derives,
# Nearest to pressure: enthalpy, thermodynamic, broadening, nostalgia, pump, increase, fw, decrease,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8471 0.0308 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8378 0.0298 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8644 0.0301 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8391 0.0302 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8567 0.0298 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8886 0.0299 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8605 0.0300 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8551 0.0297 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8895 0.0298 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8331 0.0301 sec/batch
# Nearest to his: he, was, tennyson, wit, career, hapsburg, assistant, autopsy,
# Nearest to people: novelists, writers, seattleites, autodidacts, births, dropouts, deaths, celebrities,
# Nearest to five: four, two, one, three, zero, six, eight, seven,
# Nearest to more: theorizing, and, less, better, have, some, in, only,
# Nearest to when: to, could, because, legates, had, faroes, vojt, parent,
# Nearest to is: a, the, of, as, and, in, which, this,
# Nearest to war: combatants, ii, vietnam, combat, outbreak, emergency, equivocal, condemning,
# Nearest to this: to, an, the, of, in, is, that, a,
# Nearest to applications: crelle, ergonomics, embedded, symmetries, standardise, heber, casts, enchantments,
# Nearest to existence: keita, universe, cancellation, followers, cosmology, standing, cn, subsided,
# Nearest to brother: son, emilia, younger, eldest, tyndareus, bachchan, mcfadden, eurydice,
# Nearest to quite: solent, undoubtedly, it, extrapolating, raeben, keynote, dec, infraclass,
# Nearest to liberal: conservative, party, ideology, democrat, hooking, liberalism, capitalism, dickens,
# Nearest to road: highway, lanes, tipping, ramps, barges, biking, needling, highways,
# Nearest to derived: heathens, fronting, pickford, compiles, derives, baixa, giving, nonresident,
# Nearest to pressure: enthalpy, thermodynamic, nostalgia, broadening, extent, thermodynamics, decrease, peremptory,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8589 0.0310 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8483 0.0299 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8320 0.0299 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8591 0.0300 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8642 0.0298 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8648 0.0299 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9587 0.0299 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8969 0.0298 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9079 0.0298 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8324 0.0298 sec/batch
# Nearest to his: he, was, career, assistant, tennyson, wit, autopsy, honours,
# Nearest to people: novelists, writers, births, deaths, seattleites, autodidacts, razzie, dropouts,
# Nearest to five: four, two, one, three, zero, six, seven, eight,
# Nearest to more: less, and, theorizing, with, have, better, only, some,
# Nearest to when: had, to, could, only, vojt, having, legates, blocked,
# Nearest to is: the, a, of, as, in, and, also, or,
# Nearest to war: vietnam, ii, combatants, combat, outbreak, emergency, nleutnant, germans,
# Nearest to this: an, that, to, the, of, is, in, may,
# Nearest to applications: crelle, ergonomics, symmetries, standardise, casts, embedded, heber, enchantments,
# Nearest to existence: keita, cancellation, universe, followers, cn, standing, cosmology, subsided,
# Nearest to brother: son, younger, emilia, tyndareus, eldest, mcfadden, bachchan, convalescence,
# Nearest to quite: solent, undoubtedly, it, extrapolating, raeben, keynote, dec, infraclass,
# Nearest to liberal: ideology, party, democrat, conservative, hooking, idioms, liberalism, maine,
# Nearest to road: highway, ramps, lanes, tipping, biking, needling, barges, metro,
# Nearest to derived: fronting, heathens, pickford, compiles, derives, quenya, baixa, giving,
# Nearest to pressure: enthalpy, nostalgia, thermodynamic, broadening, extent, fw, decrease, shock,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7902 0.0308 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8594 0.0298 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7896 0.0300 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8662 0.0302 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8284 0.0301 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8534 0.0301 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8951 0.0149 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8429 0.0301 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8262 0.0300 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8339 0.0301 sec/batch
# Nearest to his: he, was, father, in, died, had, tutor, after,
# Nearest to people: novelists, writers, abomination, births, obstetrician, living, americans, seattleites,
# Nearest to five: four, two, one, three, six, zero, eight, seven,
# Nearest to more: less, theorizing, and, with, have, some, better, karajan,
# Nearest to when: to, had, could, legates, only, this, the, what,
# Nearest to is: a, the, of, as, in, and, or, also,
# Nearest to war: vietnam, combat, combatants, ii, emergency, outbreak, condemning, nleutnant,
# Nearest to this: to, an, the, that, in, a, may, be,
# Nearest to applications: crelle, symmetries, ergonomics, embedded, standardise, casts, heber, enchantments,
# Nearest to existence: keita, cancellation, universe, followers, blissymbols, cn, standing, deism,
# Nearest to brother: son, younger, tyndareus, eldest, emilia, convalescence, bachchan, fern,
# Nearest to quite: solent, undoubtedly, it, extrapolating, raeben, mobilized, airport, keynote,
# Nearest to liberal: ideology, party, conservative, democrat, hooking, idioms, advocated, maine,
# Nearest to road: highway, ramps, tipping, lanes, needling, feudatories, biking, dartford,
# Nearest to derived: fronting, pickford, baixa, heathens, derives, recreates, votadini, nonresident,
# Nearest to pressure: enthalpy, nostalgia, thermodynamic, broadening, increase, shock, extent, fw,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8315 0.0311 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8148 0.0300 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8665 0.0300 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7957 0.0299 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8579 0.0301 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8303 0.0298 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8711 0.0297 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7519 0.0300 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8225 0.0302 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7827 0.0300 sec/batch
# Nearest to his: he, was, career, wit, autopsy, assistant, died, honours,
# Nearest to people: writers, births, novelists, deaths, seattleites, autodidacts, celebrities, abomination,
# Nearest to five: four, two, three, one, zero, six, seven, eight,
# Nearest to more: less, and, theorizing, some, have, with, the, better,
# Nearest to when: to, could, this, only, had, it, the, parent,
# Nearest to is: a, the, of, as, and, in, be, an,
# Nearest to war: vietnam, combat, ii, combatants, emergency, outbreak, equivocal, nleutnant,
# Nearest to this: to, the, that, an, is, in, a, be,
# Nearest to applications: crelle, symmetries, embedded, ergonomics, standardise, heber, casts, anticipations,
# Nearest to existence: keita, universe, cancellation, cn, followers, subsided, blissymbols, standing,
# Nearest to brother: son, younger, emilia, mcfadden, bachchan, eldest, tyndareus, retired,
# Nearest to quite: solent, it, undoubtedly, extrapolating, infraclass, raeben, airport, keynote,
# Nearest to liberal: party, ideology, democrat, hooking, conservative, idioms, maine, dickens,
# Nearest to road: highway, lanes, ramps, tipping, metro, streets, cavities, feudatories,
# Nearest to derived: pickford, giving, fronting, baixa, nonresident, heathens, compiles, recreates,
# Nearest to pressure: enthalpy, nostalgia, broadening, thermodynamic, extent, shock, ascetic, increase,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7732 0.0308 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8136 0.0299 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8645 0.0303 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8375 0.0301 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8079 0.0299 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8971 0.0298 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8619 0.0299 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8339 0.0300 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8125 0.0300 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8514 0.0299 sec/batch
# Nearest to his: he, career, was, autopsy, wit, died, persecutor, father,
# Nearest to people: writers, novelists, births, deaths, seattleites, americans, obituaries, obstetrician,
# Nearest to five: four, two, three, one, six, zero, seven, eight,
# Nearest to more: less, have, and, theorizing, some, better, only, with,
# Nearest to when: to, could, this, parent, it, had, legates, only,
# Nearest to is: the, a, of, as, and, in, which, be,
# Nearest to war: vietnam, combat, ii, equivocal, combatants, outbreak, emergency, hbr,
# Nearest to this: to, an, in, the, is, a, of, be,
# Nearest to applications: crelle, symmetries, ergonomics, casts, embedded, standardise, anticipations, heber,
# Nearest to existence: keita, universe, cancellation, cn, belief, cosmology, blissymbols, subsided,
# Nearest to brother: son, younger, tyndareus, eldest, emilia, mcfadden, bachchan, eurydice,
# Nearest to quite: solent, it, undoubtedly, extrapolating, keynote, raeben, mobilized, airport,
# Nearest to liberal: ideology, party, hooking, conservative, democrat, idioms, dickens, maine,
# Nearest to road: highway, tipping, ramps, lanes, biking, needling, feudatories, dartford,
# Nearest to derived: giving, derives, baixa, pickford, compiles, recreates, fronting, heathens,
# Nearest to pressure: enthalpy, nostalgia, thermodynamic, broadening, increase, extent, thermodynamics, taglioni,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8586 0.0311 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8480 0.0299 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8073 0.0299 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8655 0.0301 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8611 0.0300 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8339 0.0304 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8724 0.0301 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8589 0.0299 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8397 0.0301 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8088 0.0302 sec/batch
# Nearest to his: he, career, was, died, autopsy, tilly, elector, father,
# Nearest to people: writers, novelists, deaths, births, obituaries, americans, obstetrician, living,
# Nearest to five: four, two, three, one, six, zero, seven, eight,
# Nearest to more: and, have, less, with, of, some, the, only,
# Nearest to when: to, only, this, it, parent, could, had, a,
# Nearest to is: the, a, of, and, as, in, an, which,
# Nearest to war: vietnam, outbreak, ii, combat, emergency, equivocal, occupation, combatants,
# Nearest to this: an, is, to, a, the, of, in, be,
# Nearest to applications: crelle, symmetries, ergonomics, casts, embedded, heber, disdainful, wide,
# Nearest to existence: keita, universe, cancellation, cn, subsided, absence, followers, standing,
# Nearest to brother: son, younger, tyndareus, eldest, eurydice, emilia, mcfadden, bachchan,
# Nearest to quite: solent, it, extrapolating, undoubtedly, keynote, ltc, dec, acetic,
# Nearest to liberal: ideology, party, hooking, conservative, idioms, maine, democrat, dickens,
# Nearest to road: highway, ramps, tipping, biking, needling, dartford, lanes, cavities,
# Nearest to derived: derives, giving, heathens, fronting, pickford, compiles, baixa, meaning,
# Nearest to pressure: enthalpy, nostalgia, broadening, thermodynamic, extent, ascetic, foundation, fw,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8517 0.0317 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8344 0.0314 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8990 0.0299 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9024 0.0299 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8974 0.0299 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8640 0.0303 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7838 0.0296 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8219 0.0297 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7568 0.0299 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8698 0.0300 sec/batch
# Nearest to his: he, was, career, died, began, goethe, after, in,
# Nearest to people: writers, novelists, deaths, americans, obituaries, births, seattleites, autodidacts,
# Nearest to five: four, one, two, three, six, zero, eight, seven,
# Nearest to more: have, and, less, with, some, theorizing, only, better,
# Nearest to when: had, parent, to, only, legates, could, midgard, this,
# Nearest to is: a, of, the, as, and, in, or, an,
# Nearest to war: vietnam, ii, outbreak, equivocal, combat, combatants, hbr, emergency,
# Nearest to this: an, to, that, may, the, in, is, a,
# Nearest to applications: crelle, symmetries, ergonomics, casts, embedded, disdainful, applets, omnia,
# Nearest to existence: keita, universe, cancellation, cn, subsided, standing, followers, blissymbols,
# Nearest to brother: son, younger, tyndareus, eldest, emilia, eurydice, mcfadden, bachchan,
# Nearest to quite: solent, it, undoubtedly, extrapolating, keynote, raeben, bootleg, permanganate,
# Nearest to liberal: ideology, party, conservative, democrat, hooking, dickens, idioms, maine,
# Nearest to road: highway, tipping, ramps, needling, feudatories, cavities, darrell, lanes,
# Nearest to derived: fronting, derives, baixa, nonresident, pickford, meaning, compiles, heathens,
# Nearest to pressure: enthalpy, nostalgia, thermodynamic, broadening, increase, extent, ascetic, foundation,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8583 0.0310 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8442 0.0301 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
